# %%
pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\hp\miniconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (8.1.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (2.8.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (5.4.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (1.19.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (20.8)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (3.7.4.3)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\hp\miniconda3\lib\site-packages (from bokeh) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\miniconda3\lib\site-packages (from Jinja2>=2.7->bokeh) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hp\miniconda3\lib\site-packages (from packaging>=16.8->bokeh) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\users\hp\miniconda3\lib\site-packages (from python-dateutil>=2.1->bokeh) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\hp\miniconda3\lib\site-packages (7.6.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\miniconda3\lib\site-packages (from ipywidgets) (5.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hp\miniconda3\lib\site-packages (from ipywidgets) (5.1.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\hp\miniconda3\lib\site-packages (from ipywidgets) (7.19.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\hp\miniconda3\lib\site-packages (from ipywidgets) (5.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hp\miniconda3\lib\site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hp\miniconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: jupyter_client in c:\users\hp\miniconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.11)
# Requirement already satisfied: tornado>=4.2 in c:\users\hp\miniconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python38\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.1)
# Requirement already satisfied: pygments in c:\users\hp\miniconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.7.4)
# Requirement already satisfied: jedi>=0.10 in c:\users\hp\miniconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.17.0)
# Requirement already satisfied: pickleshare in c:\users\hp\miniconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: backcall in c:\users\hp\miniconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\miniconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hp\miniconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (50.3.1.post20201107)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hp\miniconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.14)
# Requirement already satisfied: parso>=0.7.0 in c:\users\hp\miniconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.1)
# Requirement already satisfied: ipython-genutils in c:\users\hp\miniconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\hp\miniconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\hp\miniconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.7.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\miniconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\miniconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\hp\miniconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.15.0)
# Requirement already satisfied: wcwidth in c:\users\hp\miniconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\hp\miniconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.2.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\miniconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (19.0.2)
# Requirement already satisfied: prometheus-client in c:\users\hp\miniconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\miniconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.2)
# Requirement already satisfied: jinja2 in c:\users\hp\miniconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.2)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\hp\miniconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\hp\miniconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.6.0)
# Requirement already satisfied: argon2-cffi in c:\users\hp\miniconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\miniconda3\lib\site-packages (from jupyter_client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\miniconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\hp\miniconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\hp\miniconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.3)
# Requirement already satisfied: pycparser in c:\users\hp\miniconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\miniconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: bleach in c:\users\hp\miniconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.2.3)
# Requirement already satisfied: defusedxml in c:\users\hp\miniconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: testpath in c:\users\hp\miniconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\miniconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\miniconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\miniconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: packaging in c:\users\hp\miniconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.8)
# Requirement already satisfied: webencodings in c:\users\hp\miniconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hp\miniconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

from bokeh.io import show, curdoc, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, Select, Paragraph, TextInput
from bokeh.layouts import widgetbox, column, row
from ipywidgets import interact

# %%
df = pd.read_csv('data/ocosmetic_TSNE.csv')
df.head()
# Out:
#    index                    Label           brand  \
# 0      0  Moisturizer_Combination          LA MER
# 1      1  Moisturizer_Combination           SK-II
# 2      2  Moisturizer_Combination  DRUNK ELEPHANT
# 3      3  Moisturizer_Combination          LA MER
# 4      4  Moisturizer_Combination    IT COSMETICS
#
#                                             name  price  rank  \
# 0                                Crème de la Mer    175   4.1
# 1                       Facial Treatment Essence    179   4.1
# 2                     Protini™ Polypeptide Cream     68   4.4
# 3                    The Moisturizing Soft Cream    175   3.8
# 4  Your Skin But Better™ CC+™ Cream with SPF 50+     38   4.1
#
#                                          ingredients  Combination  Dry  \
# 0  Algae (Seaweed) Extract, Mineral Oil, Petrolat...            1    1
# 1  Galactomyces Ferment Filtrate (Pitera), Butyle...            1    1
# 2  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...            1    1
# 3  Algae (Seaweed) Extract, Cyclopentasiloxane, P...            1    1
# 4  Water, Snail Secretion Filtrate, Phenyl Trimet...            1    1
#
#    Normal  Oily  Sensitive          X          Y
# 0       1     1          1  22.824793   9.365267
# 1       1     1          1  -7.036584  -5.617220
# 2       1     1          0 -37.718820  -0.568541
# 3       1     1          1  -1.414053 -33.328260
# 4       1     1          1  24.502514  35.757576

# %%
df.columns
# Out:
# Index(['index', 'Label', 'brand', 'name', 'price', 'rank', 'ingredients',
#        'Combination', 'Dry', 'Normal', 'Oily', 'Sensitive', 'X', 'Y'],
#       dtype='object')

# %%
df.Label.unique()
# Out:
# array(['Moisturizer_Combination', 'Moisturizer_Dry', 'Moisturizer_Normal',
#        'Moisturizer_Oily', 'Moisturizer_Sensitive',
#        'Cleanser_Combination', 'Cleanser_Dry', 'Cleanser_Normal',
#        'Cleanser_Oily', 'Cleanser_Sensitive', 'Treatment_Combination',
#        'Treatment_Dry', 'Treatment_Normal', 'Treatment_Oily',
#        'Treatment_Sensitive', 'Face Mask_Combination', 'Face Mask_Dry',
#        'Face Mask_Normal', 'Face Mask_Oily', 'Face Mask_Sensitive',
#        'Eye cream_Combination', 'Eye cream_Dry', 'Eye cream_Normal',
#        'Eye cream_Oily', 'Eye cream_Sensitive', 'Sun protect_Combination',
#        'Sun protect_Dry', 'Sun protect_Normal', 'Sun protect_Oily',
#        'Sun protect_Sensitive'], dtype=object)

# %%
option_1 = ['Moisturizer', 'Cleanser', 'Treatment', 'Face Mask', 'Eye cream', 'Sun protect']
option_2 = ['Combination', 'Dry', 'Normal', 'Oily', 'Sensitive']

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# make a source and scatter bokeh plot  
source = ColumnDataSource(df)
plot = figure(x_axis_label = 'T-SNE 1', y_axis_label = 'T-SNE 2', 
              width = 500, height = 400)
plot.circle(x = 'X', y = 'Y', source = source, 
            size = 10, color = '#FF7373', alpha = .8)

plot.background_fill_color = "beige"
plot.background_fill_alpha = 0.2

# add hover tool
hover = HoverTool(tooltips = [
        ('Item', '@name'),
        ('brand', '@brand'),
        ('Price', '$ @price'),
        ('Rank', '@rank')])
plot.add_tools(hover)

# %%
# define the callback
def update(op1 = option_1[0], op2 = option_2[0]):
    a_b = op1 + '_' + op2
    new_data = {
        'X' : df[df['Label'] == a_b]['X'],
        'Y' : df[df['Label'] == a_b]['Y'],
        'name' : df[df['Label'] == a_b]['name'],
        'brand' : df[df['Label'] == a_b]['brand'],
        'price' : df[df['Label'] == a_b]['price'],
        'rank' : df[df['Label'] == a_b]['rank'],
    }
    source.data = new_data
    push_notebook()

# %%
# interact the plot with callback 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1042">Loading BokehJS ...</span>
#     </div>

# %%
interact(update, op1 = option_1, op2 = option_2)
show(plot, notebook_handle = True)
# Out:
# C:\Users\HP\miniconda3\lib\site-packages\bokeh\io\notebook.py:252: UserWarning: Cannot find a last shown plot to update. Call output_notebook() and show(..., notebook_handle=True) before push_notebook()
#   warn("Cannot find a last shown plot to update. Call output_notebook() and show(..., notebook_handle=True) before push_notebook()")
#   <div class="bk-root" id="bde7b28c-e325-43b8-b3ca-74a9601bf5ab" data-root-id="1004"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %%
df_2 = df[df.Label == 'Moisturizer_Dry'].reset_index().drop('index', axis = 1)
df_2['dist'] = 0.0

myItem = df_2[df_2.name.str.contains('Peat Miracle Revital')]
myItem
# Out:
#     level_0            Label  brand                        name  price  rank  \
# 87      286  Moisturizer_Dry  BELIF  Peat Miracle Revital Cream     58   4.7
#
#                                           ingredients  Combination  Dry  \
# 87  Water, Dipropylene Glycol, Glycerin, Caprylic/...            1    1
#
#     Normal  Oily  Sensitive         X         Y  dist
# 87       1     0          0  1.016416 -4.042279   0.0

# %%
# getting the array for myItem
P1 = np.array([myItem.X.values, myItem.Y.values]).reshape(1, -1)
P1
# Out:
# array([[ 1.016416 , -4.0422792]])
